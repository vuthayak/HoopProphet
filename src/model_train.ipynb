# %%
# Model imports
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# Model evaluation imports
from sklearn.metrics import mean_squared_error, r2_score

# Cross-validation imports
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score

# Data preprocessing imports
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Hyperparameter tuning imports
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# Function to load dataset
def load_data(file_path):
    """
    Load dataset from a CSV file.
    
    Parameters:
    file_path (str): Path to the CSV file.
    
    Returns:
    pd.DataFrame: Loaded dataset.
    """
    data = pd.read_csv(file_path)
    print(f"Data loaded from {file_path} with shape {data.shape}")
    return data

data = load_data('../data/dataset.csv')
data.set_index("Game_ID", inplace=True)

prop_line = load_data('../data/avg_career_stats.csv')

data
# Out:
# Data loaded from ../data/dataset.csv with shape (86, 15)
# Data loaded from ../data/avg_career_stats.csv with shape (1, 6)
#           PTS  REB  AST  STL  BLK  FG3M  TRIPLE_DOUBLE  DOUBLE_DOUBLE  W  \
# Game_ID
# 22401192    0    0    0    0    0     0              0              0  0
# 22401171   36    6   12    0    2     3              0              1  0
# 22401167   36    2    8    1    1     2              0              0  1
# 22401144   35    3    5    2    0     1              0              0  0
# 22401129   25    9    4    0    1     2              0              0  0
# ...       ...  ...  ...  ...  ...   ...            ...            ... ..
# 22400063   28    5    8    1    0     2              0              0  0
# 22300857   21    3   10    1    0     2              0              1  0
# 22300675   19    2    7    2    1     2              0              0  0
# 22300283   23    8   11    2    0     3              0              1  0
# ...

# %%
# Setting up K-Folds
rkf = RepeatedKFold(n_splits=10, n_repeats=10, random_state=101)

# TODO: Set up for loop to do this for all stats and models
# TODO: Do GridSearchCV for tree models
X = data.drop(columns=['PTS'])
y = data['PTS']

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LinearRegression())])

# Cross-validation
cv_results = cross_val_score(pipeline, X, y, cv=rkf, scoring='r2')

# TODO: Store info in a dictionary for each stat
print(cv_results.mean(), cv_results.std())
# Out:
# 0.554176253065658 0.46396913204203405
